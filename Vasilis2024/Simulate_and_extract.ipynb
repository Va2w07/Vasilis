# %%
import numpy as np
import random
from matplotlib import pyplot as plt
 
def simulate_reference(L, deltat):
    toff=1.0e-11
    twidth=8.0e-13
    tdecay=1.0e-12
    scale=1.0e12
    x=np.zeros(L, float)
    for t in range(0,L):
        T=t*deltat - toff
        x[t]=-scale*T* np.exp(-(T/twidth)**2 - T/tdecay)

    return x

deltat=0.0194e-12
L=2**11
x=simulate_reference(L, deltat)
t_axis = np.arange(0,L*deltat, deltat)
f_axis = np.fft.fftfreq(L, deltat)
X = np.fft.fft(x)
X = np.fft.fftshift(X)
f_axis = np.fft.fftshift(f_axis)
plt.figure()
plt.plot(f_axis, np.abs(X))
plt.xlim(0,3e12)
plt.xlabel('Frequency, f [Hz]')
plt.figure()

plt.plot(t_axis*1e12, x)
plt.xlabel('Time, t [ps]')
# Out:
# Text(0.5, 0, 'Time, t [ps]')

# %% [markdown]
# Creates a pulse with following equation $x(t) = A*T*\exp{(-(\frac{T}{t_{width}})^2 - \frac{T}{\tau})}$ where $T = t-t_{offset}$ to centre the pulse at some delay time (in this case 10 ps), $A$ is just a scaling factor, $\tau$ is a decay rate, $t_{width}$ is a factor that gives a width the pulse.
#
# This is what is used for the simulation and is the reference as well. ie this a pulse that has been through the equivelent thickness of air already, as the simulations take this into account...

# %%
def rts(n0, nj, Dj):
    "returns tuple of r, t and t**2 - r**2 for layer j"
    c=np.cos(nj*Dj)
    s=np.sin(nj*Dj)
    d=c + (0.5J)*(nj/n0 + n0/nj)*s
    r=(0.5J)*s*(n0/nj - nj/n0)/d
    t=1.0/d
# note transmission coeff phase is relative to n0 and kD
# s phase which is used to compute reflection coeff is relative to input
    return (r, t*np.exp((1J)*n0*Dj), t*t-r*r)

def RTm(m, n0, layers):
    "Reflection and Transmission coefficients for m layers"
    U=0.0; V=1.0; T=1.0; R=0.0
    for j in range(0,m):
        nj=layers[j][0]
        Dj=layers[j][1]
        (r,t,s)=rts(n0, nj, Dj)
        Vlast=V
        (U,V)=(r*V + s*U, V - r*U)
        T=T*t*Vlast/V
        R=U/V
    return (R,T)

def simulate_parallel(x, layers, deltat, noise_level):
    L=len(x)
# convolution done with 4*L points
    M=2*L
    N=4*L
# wave number for frequency point k is k*dk
    deltaf=1.0/(N*deltat)
    dk=2*np.pi*deltaf/2.9979e8
    m=len(layers)
    indices=    np.array([l[0] for l in layers])
    thicknesses=np.array([l[1] for l in layers])
    T=np.zeros(N, complex)
    for k in range(0,M+1):
        kD=k*dk*thicknesses
        nkD=np.array([(indices[l],kD[l]) for l in range(0,m)])
        T[k]=RTm(m, 1.0, nkD)[1]
    for k in range(1,M): T[N-k]=np.conjugate(T[k])
    z=np.zeros(N, float)
    z[0:L]=x[0:L]
    X=np.fft.fft(z)/N
    Y=T*X
    y=N*np.fft.ifft(Y).real + noise_level*np.random.randn(N)
    return (N,deltaf,T,y)

layers=[(2.0-0.1J, 1.0e-3), (3.0, 0.1e-3), (2.0, 1.0e-3)] #FIRST TERM n, SECOND TERM d.
#layers=[(1.0, 100.0e-3)]
(N,deltaf,T,y)=simulate_parallel(x, layers, deltat, 0.00)
# truncate to L points
y=y[0:L]
plt.figure()
plt.plot(t_axis,x,t_axis,y)
f_axis = np.arange(0,N*deltaf, deltaf)
plt.figure()
plt.plot(f_axis, np.abs(T))
plt.xlim(0,3e12)
plt.xlabel('Frequency, f [Hz]')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 51
#      49 layers=[(2.0-0.1J, 1.0e-3), (3.0, 0.1e-3), (2.0, 1.0e-3)] #FIRST TERM n, SECOND TERM d.
#      50 #layers=[(1.0, 100.0e-3)]
# ---> 51 (N,deltaf,T,y)=simulate_parallel(x, layers, deltat, 0.00)
#      52 # truncate to L points
#      53 y=y[0:L]
#
# NameError: name 'x' is not defined

# %% [markdown]
# Here's an example of the simulation running muliple layers, n = 2,3,2 and d = 1,0.1,1 mm respectively

# %% [markdown]
# # Examples

# %% [markdown]
# ## One slab, n = 2.5, d = 0.4 mm

# %%
layers=[(3-0.01J, 0.3e-3)] #FIRST TERM n, SECOND TERM d.
#layers=[(1.0, 100.0e-3)]
(N,deltaf,T,y)=simulate_parallel(x, layers, deltat, 0.0002)
# truncate to L points
y=y[0:L]

plt.plot(t_axis,x,t_axis,y)
plt.figure()
plt.plot(f_axis, np.abs(T))
plt.xlim(0,3e12)
plt.xlabel('Frequency, f [Hz]')
plt.show()

# %% [markdown]
# ## One slab, n = 3, d = 0.1 mm

# %%
layers=[(3, 0.05e-3)] #FIRST TERM n, SECOND TERM d.
#layers=[(1.0, 100.0e-3)]
(N,deltaf,T,y)=simulate_parallel(x, layers, deltat, 0)
# truncate to L points
y=y[0:L]

plt.plot(t_axis*10**12,x,t_axis*10**12,y)
# Out:
# [<matplotlib.lines.Line2D at 0x11c695220>,
#  <matplotlib.lines.Line2D at 0x11c695310>]

# %% [markdown]
# ## Three layers, n = [2.2, 2.5 - 0.05i, 2.2], d = [0.2, 0.1, 0.2] mm

# %%
layers=[(2.2, 0.2e-3),(2.5 - 0.1j,0.1e-3),(2.2, 0.2e-3)] #FIRST TERM n, SECOND TERM d.
#layers=[(1.0, 100.0e-3)]
(N,deltaf,T,y)=simulate_parallel(x, layers, deltat, 0.002)
# truncate to L points
y=y[0:L]

plt.plot(t_axis,x,t_axis,y)
# Out:
# [<matplotlib.lines.Line2D at 0x11c70be80>,
#  <matplotlib.lines.Line2D at 0x11c70bf70>]
